# %%
import tensorflow as tf

# シンプルなモデルの構築とトレーニング
model = tf.keras.Sequential([
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu', input_shape=(28, 28, 1)),
    tf.keras.layers.MaxPooling2D((2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# ダミーデータを生成してトレーニング
import numpy as np
x_train = np.random.random((100, 28, 28, 1)).astype(np.float32)
y_train = np.random.randint(0, 10, (100,))
model.fit(x_train, y_train, epochs=1)
# Out:
# Could not connect to 127.0.0.1: 33457
# Traceback (most recent call last):
#   File "/.jbdevcontainer/JetBrains/RemoteDev/dist/9e53f9d1f7e88_pycharm-professional-2024.3.1.1/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_comm.py", line 467, in start_client
#     s.connect((host, port))
# ConnectionRefusedError: [Errno 111] Connection refused
# Traceback (most recent call last):
#   File "/.jbdevcontainer/JetBrains/RemoteDev/dist/9e53f9d1f7e88_pycharm-professional-2024.3.1.1/plugins/python/helpers-pro/jupyter_debug/pydev_jupyter_utils.py", line 81, in attach_to_debugger
#     debugger.connect(pydev_localhost.get_localhost(), debugger_port)
#   File "/.jbdevcontainer/JetBrains/RemoteDev/dist/9e53f9d1f7e88_pycharm-professional-2024.3.1.1/plugins/python-ce/helpers/pydev/pydevd.py", line 704, in connect
#     s = start_client(host, port)
#         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/.jbdevcontainer/JetBrains/RemoteDev/dist/9e53f9d1f7e88_pycharm-professional-2024.3.1.1/plugins/python-ce/helpers/pydev/_pydevd_bundle/pydevd_comm.py", line 467, in start_client
#     s.connect((host, port))
# ConnectionRefusedError: [Errno 111] Connection refused
# Failed to connect to target debugger.
